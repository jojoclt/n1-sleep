# %% [markdown]
# # Import libraries

# %%
import sys
sys.path.append("../src/")
import os

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly_resampler import FigureResampler

# %%
from tqdm.auto import tqdm
# Preprocessing
from scipy.signal import butter, lfilter
from tsflex.processing import SeriesPipeline, SeriesProcessor
# Extract Features
import antropy as ant
import scipy.stats as ss
from yasa import bandpower
import scipy.stats as ss
from tsflex.features import (
    FeatureCollection,
    FuncWrapper,
    MultipleFeatureDescriptors,
    FuncWrapper,
)
from tsflex.features.integrations import tsfresh_settings_wrapper

# %%
from data import load_signals, load_annotations, annotation_to_30s_labels

# %% [markdown]
# # Extract Features

# %% [markdown]
# ## Load Data

# %%
data_folder = "../data/clips/"
dfs = []
sorted_files = sorted(os.listdir(data_folder))
psg_hypnogram_files = [(p, h) for p, h in zip(sorted_files[::2], sorted_files[1:][::2])]
df_files = pd.DataFrame(psg_hypnogram_files, columns=["psg_file", "label_file"])
df_files["patient_id"] = df_files.psg_file.apply(lambda f: f[:5])
df_files["file_id"] = df_files.psg_file.apply(lambda f: f[:6])
df_files["clip_id"] = df_files.psg_file.apply(lambda f: f[:7])
df_files
# Out:
#                 psg_file                label_file patient_id file_id  clip_id
# 0     SC400100E0-PSG.edf  SC400100EC-Hypnogram.edf      SC400  SC4001  SC40010
# 1     SC400101E0-PSG.edf  SC400101EC-Hypnogram.edf      SC400  SC4001  SC40010
# 2     SC400102E0-PSG.edf  SC400102EC-Hypnogram.edf      SC400  SC4001  SC40010
# 3     SC400103E0-PSG.edf  SC400103EC-Hypnogram.edf      SC400  SC4001  SC40010
# 4     SC400104E0-PSG.edf  SC400104EC-Hypnogram.edf      SC400  SC4001  SC40010
# ...                  ...                       ...        ...     ...      ...
# 3299  SC482226G0-PSG.edf  SC482226GC-Hypnogram.edf      SC482  SC4822  SC48222
# 3300  SC482227G0-PSG.edf  SC482227GC-Hypnogram.edf      SC482  SC4822  SC48222
# 3301  SC482228G0-PSG.edf  SC482228GC-Hypnogram.edf      SC482  SC4822  SC48222
# 3302  SC482229G0-PSG.edf  SC482229GC-Hypnogram.edf      SC482  SC4822  SC48222
# 3303  SC482230G0-PSG.edf  SC482230GC-Hypnogram.edf      SC482  SC4822  SC48223
#
# [3304 rows x 5 columns]

# %%
PATIENT_IDX = 0
signal_dict = {}

for idx in range(len(df_files)):
    sig, freq = load_signals(
        data_folder + "/" + df_files.iloc[idx].psg_file,
        only_info=True,
    )
    for s, f in zip(sig, freq):
        if (s, f) in signal_dict.keys():
            signal_dict[(s, f)].append(idx)
        else:
            signal_dict[(s, f)] = [idx]

common_signals = [
    'EEG Fpz-Cz', 'EEG Pz-Oz', 'EOG horizontal',  # All have the same sampling rate (100 Hz)
    'EMG submental',  # Also 100 Hz
]

data = load_signals(
    data_folder + "/" + df_files.iloc[PATIENT_IDX].psg_file,
    retrieve_signals=common_signals,
)
annotations = load_annotations(
    data_folder + "/" + df_files.iloc[PATIENT_IDX].label_file,
    data_folder + "/" + df_files.iloc[PATIENT_IDX].psg_file,
)

# %% [markdown]
# ### Plot 1 Patient's Data

# %%
# Used for plotting
cats = [
    "Sleep stage ?",
    "Movement time",
    "Sleep stage W",
    "Sleep stage 1",
    "Sleep stage 2",
    "Sleep stage 3",
    "Sleep stage 4",
    "Sleep stage R",
][::-1]

idxs = [s.name for s in data]

fig = FigureResampler(
    make_subplots(
        rows=len(idxs) + 1,
        cols=1,
        shared_xaxes=True,
        subplot_titles=idxs + ["Hypnogram"],
        vertical_spacing=0.05,
    ),
    default_n_shown_samples=3_000,
)

for idx, s in enumerate(data, 1):
    fig.add_trace(
        go.Scattergl(
            x=[], y=[], name=s.name, line_width=1,
        ),
        hf_x=s.index,
        hf_y=s.values,
        row=idx,
        col=1,
    )

fig.add_trace(
    go.Scattergl(
        x=[], y=[], name="Hypnogram", line_width=1.5, line_shape="hv",
    ),
    hf_x=annotation_to_30s_labels(annotations).index,
    hf_y=annotation_to_30s_labels(annotations)["label"].astype("category"),
    row=len(idxs) + 1,
    col=1,
)

fig.update_layout(height=900)
fig.update_yaxes(categoryorder="array", categoryarray=cats)

fig.update_layout(
    legend_traceorder="normal",
    template="plotly_white",
    #     legend=dict(orientation="h", y=1.07, xanchor="right", x=1),
)

fig.show_dash(port=8043)

# %% [markdown]
# ## Preprocess by bandpass filter

# %%
def butter_bandpass_filter(sig, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype="band")
    y = lfilter(b, a, sig)
    return y

eeg_bandpass = SeriesProcessor(
    function=butter_bandpass_filter,
    series_names=["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal"],
    lowcut=0.4,
    highcut=30,
    fs=100,
)

emg_bandpass = SeriesProcessor(
    function=butter_bandpass_filter,
    series_names=["EMG submental"],
    lowcut=0.5,
    highcut=10,
    fs=100,
)

process_pipe = SeriesPipeline([eeg_bandpass, emg_bandpass])
data_processed = process_pipe.process(data, return_all_series=True)
# Out:
# 08-Jun-23 12:28:05 | INFO | Finished function [butter_bandpass_filter] on [('EEG Fpz-Cz',), ('EEG Pz-Oz',), ('EOG horizontal',)] in [0.006893634796142578 seconds]!
# 08-Jun-23 12:28:05 | INFO | Finished function [butter_bandpass_filter] on [('EMG submental',)] in [0.0006701946258544922 seconds]!

# %% [markdown]
# ### Plot 1 Patient's Preprocessed data
# The cell "Plot 1 Patient's Data" should be executed first.

# %%
for s in data_processed:
    idx = idxs.index(s.name.split("_")[-1]) + 1
    fig.add_trace(
        go.Scatter(x=[], y=[], name=s.name + " processed", line_width=1),
        hf_x=s.index,
        hf_y=s.values,
        row=idx,
        col=1,
    )
    
fig.show_dash(port=8043)

# %% [markdown]
# # Extract Features from all Patients

# %% [markdown]
# ## Feature Extraction

# %%
tsfresh_settings = {
    "fft_aggregated": [
        {"aggtype": "centroid"},
        {"aggtype": "variance"},
        {"aggtype": "skew"},
        {"aggtype": "kurtosis"},
    ],
    "fourier_entropy": [
        {"bins": 2},
        {"bins": 3},
        {"bins": 5},
        {"bins": 10},
        {"bins": 30},
        {"bins": 60},
        {"bins": 100},
    ],
    "binned_entropy": [
        {"max_bins": 5},
        {"max_bins": 10},
        {"max_bins": 30},
        {"max_bins": 60},
    ],
}

def wrapped_higuchi_fd(x):
    x = np.array(x, dtype="float64")
    return ant.higuchi_fd(x)

def wrapped_bandpowers(x, sf, bands):
    return bandpower(x, sf=sf, bands=bands).values[0][:-2]

bands = [
    (0.4, 1, "sdelta"),
    (1, 4, "fdelta"),
    (4, 8, "theta"),
    (8, 12, "alpha"),
    (12, 16, "sigma"),
    (16, 30, "beta"),
]
bandpowers_ouputs = [b[2] for b in bands] + ["TotalAbsPow"]

# %%
time_funcs = [
    np.std,
    ss.iqr,
    ss.skew,
    ss.kurtosis,
    ant.num_zerocross,
    FuncWrapper(
        ant.hjorth_params, output_names=["horth_mobility", "hjorth_complexity"]
    ),
    wrapped_higuchi_fd,
    ant.petrosian_fd,
    ant.perm_entropy,
] + tsfresh_settings_wrapper(tsfresh_settings)

freq_funcs = [
    FuncWrapper(wrapped_bandpowers, sf=100, bands=bands, output_names=bandpowers_ouputs)
]

time_feats = MultipleFeatureDescriptors(
    time_funcs,
    ["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal", "EMG submental"],
    windows=["30s", "60s", "90s"],
    strides="30s",
)
freq_feats = MultipleFeatureDescriptors(
    freq_funcs,
    ["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal"],
    windows=["30s", "60s", "90s"],
    strides="30s",
)

feature_collection = FeatureCollection([time_feats, freq_feats])
feats = feature_collection.calculate(data_processed, return_df=True, show_progress=True)
# Out:
#   0%|          | 0/261 [00:00<?, ?it/s]
# 08-Jun-23 12:28:10 | INFO | Finished function [skew] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.005666971206665039 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.00469517707824707 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [perm_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.012369155883789062 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [hjorth_params] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.003161191940307617 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [std] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0013949871063232422 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [iqr] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004609107971191406 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.01328277587890625 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [kurtosis] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.00454401969909668 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [num_zerocross] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.001157999038696289 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.051484107971191406 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [petrosian_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0016300678253173828 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.053611040115356445 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.059378862380981445 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.03856015205383301 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.014071941375732422 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.00608062744140625 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.011759757995605469 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.06145000457763672 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [iqr] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005243778228759766 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004542112350463867 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004155874252319336 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [std] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0009701251983642578 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.018421173095703125 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [skew] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005041837692260742 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [hjorth_params] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0029611587524414062 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [num_zerocross] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0033159255981445312 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [petrosian_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0015370845794677734 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.013022899627685547 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.01668405532836914 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [kurtosis] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.04823875427246094 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.01984095573425293 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.03707003593444824 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.017628908157348633 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.018090009689331055 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.03942108154296875 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [perm_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0460820198059082 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.015269756317138672 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010881900787353516 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004907131195068359 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.04412388801574707 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.006561994552612305 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [std] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0054988861083984375 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [iqr] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.009873151779174805 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0010738372802734375 seconds]!
# 08-Jun-23 12:28:10 | INFO | Finished function [skew] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005525350570678711 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.014108896255493164 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.01191401481628418 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.22974371910095215 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0029380321502685547 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.004059791564941406 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0072460174560546875 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.024840831756591797 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.028567075729370117 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.012203693389892578 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0861821174621582 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.054045915603637695 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.06086587905883789 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.04877638816833496 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.05025172233581543 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.010064125061035156 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0059888362884521484 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.022576093673706055 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.01919698715209961 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.04868769645690918 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.21884584426879883 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.01787877082824707 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0012509822845458984 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.014777183532714844 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0010018348693847656 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.015173912048339844 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.019672155380249023 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0036630630493164062 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0016620159149169922 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.02011585235595703 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.008688926696777344 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.017522335052490234 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.012916803359985352 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.013112068176269531 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.010000944137573242 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0441279411315918 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.061016082763671875 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.04575204849243164 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.009989023208618164 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0044209957122802734 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004201173782348633 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Fpz-Cz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.17973875999450684 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0009350776672363281 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0052852630615234375 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0008590221405029297 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.01820063591003418 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.002798795700073242 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004970073699951172 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0026047229766845703 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0013110637664794922 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004098653793334961 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.013652801513671875 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.01982903480529785 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010802030563354492 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010916948318481445 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010949850082397461 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.011945962905883789 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.029736042022705078 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.01185917854309082 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0060689449310302734 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.011276006698608398 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Pz-Oz',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.13280892372131348 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0010309219360351562 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.00486302375793457 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.030198097229003906 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.009654998779296875 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0010759830474853516 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005156993865966797 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.006475925445556641 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005192279815673828 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.009666919708251953 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.003312826156616211 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.013681888580322266 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.014954090118408203 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.03297996520996094 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.02759385108947754 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.03260087966918945 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.03635883331298828 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.04442286491394043 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.024507999420166016 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005585193634033203 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.013724803924560547 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.01134800910949707 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.011750221252441406 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.021488189697265625 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0511929988861084 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004321098327636719 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.18182897567749023 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0011479854583740234 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0009331703186035156 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.008849859237670898 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.008893251419067383 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0013549327850341797 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0068209171295166016 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0013098716735839844 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.018218994140625 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.016108036041259766 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.017767906188964844 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.016448020935058594 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.024058818817138672 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.01424264907836914 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.023571014404296875 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.00534510612487793 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.011727094650268555 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.02048492431640625 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EEG Pz-Oz',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.14644384384155273 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004342079162597656 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0041348934173583984 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0041348934173583984 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0009310245513916016 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0008151531219482422 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005010843276977539 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004828929901123047 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.006186962127685547 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010617971420288086 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.011031150817871094 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0041501522064208984 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [perm_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.015499114990234375 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.022379159927368164 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.011096000671386719 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.011101007461547852 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.010865926742553711 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.030863285064697266 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.018910884857177734 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005070924758911133 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_bandpowers] on [('EOG horizontal',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.11481904983520508 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005010128021240234 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004766941070556641 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.004843950271606445 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.03126406669616699 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.039647817611694336 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [std] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.001024007797241211 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [skew] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0050580501556396484 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [num_zerocross] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0010669231414794922 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [iqr] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0061528682708740234 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [hjorth_params] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.003045797348022461 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [wrapped_higuchi_fd] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0033898353576660156 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [kurtosis] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.004189014434814453 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [petrosian_fd] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0015380382537841797 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.011967182159423828 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.011892080307006836 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.012071847915649414 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.017306089401245117 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [perm_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.05582785606384277 seconds]!
# 08-Jun-23 12:28:11 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.031332969665527344 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.011827945709228516 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [wrapped_bandpowers] on [('EOG horizontal',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.10728716850280762 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.012130022048950195 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005918979644775391 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0058939456939697266 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.005522966384887695 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.011935949325561523 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [std] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0007090568542480469 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [kurtosis] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0032820701599121094 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [iqr] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.002473115921020508 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [skew] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.004189968109130859 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.025227069854736328 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [hjorth_params] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0020308494567871094 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [num_zerocross] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0003070831298828125 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [petrosian_fd] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0006539821624755859 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [wrapped_higuchi_fd] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0002548694610595703 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.003525972366333008 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [perm_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0019299983978271484 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.01225590705871582 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.007723093032836914 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.03984189033508301 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.003064870834350586 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.007692098617553711 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.007607221603393555 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.00767207145690918 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0031380653381347656 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.03755593299865723 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [wrapped_bandpowers] on [('EOG horizontal',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.13163495063781738 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0031769275665283203 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [std] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0007011890411376953 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:00:30, 0 days 00:00:30] in [0.0030829906463623047 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [iqr] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.002402067184448242 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [kurtosis] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0032830238342285156 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [hjorth_params] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.001978158950805664 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [wrapped_higuchi_fd] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0002338886260986328 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [skew] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0039980411529541016 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [num_zerocross] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.00033211708068847656 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [petrosian_fd] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.000640869140625 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [perm_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.012109756469726562 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.016850948333740234 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.007287263870239258 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.020267009735107422 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.014148950576782227 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.016047954559326172 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.007481098175048828 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.007503986358642578 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0073528289794921875 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.005373954772949219 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.0030748844146728516 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.003072977066040039 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:00, 0 days 00:00:30] in [0.00304412841796875 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [skew] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.003885984420776367 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [std] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0006709098815917969 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [kurtosis] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0031690597534179688 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [iqr] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0024101734161376953 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [num_zerocross] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.00030493736267089844 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [wrapped_higuchi_fd] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.00023412704467773438 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [petrosian_fd] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0006577968597412109 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [hjorth_params] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0019402503967285156 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [perm_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.001889944076538086 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007550954818725586 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007497072219848633 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [[tsfresh-combiner_wrapped]__fft_aggregated] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.013004064559936523 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.01810598373413086 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007158041000366211 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007205009460449219 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007328033447265625 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0029730796813964844 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [fourier_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.007233858108520508 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.0029981136322021484 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.002995014190673828 seconds]!
# 08-Jun-23 12:28:12 | INFO | Finished function [binned_entropy] on [('EMG submental',)] with window-stride [0 days 00:01:30, 0 days 00:00:30] in [0.003056049346923828 seconds]!

# %% [markdown]
# ## Pipeline for all Patients

# %%
df_feats = []
for psg_file, hypnogram_file in tqdm(zip(df_files.psg_file, df_files.label_file)):
    file_folder = data_folder + "/"
    # Load the data, process the data and extract features
    data = load_signals(file_folder + psg_file)
    data_processed = process_pipe.process(data)
    df_feat = feature_collection.calculate(
        data_processed, return_df=True, window_idx="begin"
    ).astype("float32")
    # Add the labels (and reduce features to only data for which we have labels)
    annotations = load_annotations(file_folder + hypnogram_file, file_folder + psg_file)
    annotations = annotation_to_30s_labels(annotations)
    df_feat = df_feat.merge(annotations, left_index=True, right_index=True)
    # Add the file name & folder
    df_feat["psg_file"] = psg_file
    df_feat["patient_id"] = psg_file[:5]
    df_feat["file_id"] = psg_file[:6]
    df_feat["clip_id"] = psg_file[:7]
    # Collect the dataframes
    df_feats += [df_feat]

df_feats = pd.concat(df_feats)
df_feats.rename(columns={"description": "label"}, inplace=True)
# Out:
# 0it [00:00, ?it/s]
# Exception ignored in: <function _releaseLock at 0x7fa650367d30>
# Traceback (most recent call last):
#   File "/Users/wangyanting/opt/anaconda3/envs/BCI_2023/lib/python3.8/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:

# %%
df_feats.to_csv('/caches/cache_clip.csv')
df_feats.to_parquet("../features/sleep-edf_cassette_clip_features_ALL_90s.parquet")
